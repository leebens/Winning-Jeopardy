# %% [markdown]
# # Winning Jeopardy

# %% [markdown]
# Jeopardy is a popular TV show in the US where participants answer questions to win money. It's been running for a few decades, and is a major force in popular culture. Let's say you want to compete on Jeopardy, and you're looking for any edge you can get to win. In this project, I'll work with a dataset of Jeopardy questions to figure out some patterns in the questions that could help you win.
#
# The dataset is named jeopardy.csv, and contains 20000 rows from the beginning of a full dataset of Jeopardy questions, which you can download here: https://www.reddit.com/r/datasets/comments/1uyd0t/200000_jeopardy_questions_in_a_json_file.

# %%
import pandas as pd
import re 
import random
from scipy.stats import chisquare
import numpy as np

# %%
jeopardy = pd.read_csv('jeopardy.csv')
jeopardy.head(5)
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
jeopardy.columns
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %%
#Remove spaces in front of columns
jeopardy.columns = ['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question', 'Answer']

# %% [markdown]
# ## Clean and prepare the dataset

# %%
#Write a function to normalize questions and answers
def normalizer(words):
    punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    words = words.lower()
    for ele in words:  
        if ele in punc:  
            words = words.replace(ele, "")  
    return words
        
#Normalize the Question column    
jeopardy['clean_question'] = jeopardy['Question'].apply(normalizer)

#Normalize the Answer column    
jeopardy['clean_answer'] = jeopardy['Answer'].apply(normalizer)

# %%
#Write a function to normalize dollar values
def dollar_normalizer(numbers):
    punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    for ele in numbers:  
        if ele in punc:  
            numbers = numbers.replace(ele, "") 
    try:
        numbers = int(numbers)
    except:
        numbers = int(0)
    return numbers

#Normalize the Value column
jeopardy['clean_value'] = jeopardy['Value'].apply(dollar_normalizer)

# %%
#Use the pandas.to_datetime function to convert the Air Date column to a datetime column.
jeopardy['Air Date'] = pd.to_datetime(jeopardy['Air Date'])

# %% [markdown]
# ## What to examine

# %% [markdown]
# In order to figure out whether to study past questions, study general knowledge, or not study it all, it would be helpful to figure out two things:
#
# - How often the answer is deducible from the question.
# - How often new questions are repeats of older questions.
#
# We can answer the second question by seeing how often complex words (> 6 characters) reoccur. We can answer the first question by seeing how many times words in the answer also occur in the question. We'll work on the first question now, and come back to the second.

# %% [markdown]
# ### Question 1: How many times words in the answer also occur in the question

# %%
def repeat_counter(row):
    split_answer = row['clean_answer'].split()
    split_question = row['clean_question'].split()
    match_count = 0
    if "the" in split_answer: #The is commonly found in answers and questions, but doesn't have any meaningful use in finding the answer.
        split_answer.remove("the")
    if len(split_answer) == 0:
        return 0
    else:
        for item in split_answer:
            if (item in split_question):
                match_count += 1
        return match_count/len(split_answer)
    
#Count how many times terms in clean_answer occur in clean_question
jeopardy["answer_in_question"] = jeopardy.apply(repeat_counter, axis=1)

# %%
#Find the mean of the answer_in_question column using the mean method on Series.
print('The mean is {0}%'.format(round(jeopardy["answer_in_question"].mean()*100),0))
print('So on average, the answer only makes up for about 6% of the question. This isn\'t a huge number, and means that we probably can\'t just hope that hearing a question will enable us to figure out the answer. We\'ll probably have to study.')
# Out:
# The mean is 6.0%
# So on average, the answer only makes up for about 6% of the question. This isn't a huge number, and means that we probably can't just hope that hearing a question will enable us to figure out the answer. We'll probably have to study.

# %% [markdown]
# ### Question 2: How often new questions are repeats of older questions.

# %% [markdown]
# We can't completely answer this, because we only have about 10% of the full Jeopardy question dataset, but we can investigate it at least.

# %%
jeopardy
# Out:
#        Show Number   Air Date             Round  \
# 19325           10 1984-09-21   Final Jeopardy!
# 19305           10 1984-09-21  Double Jeopardy!
# 19306           10 1984-09-21  Double Jeopardy!
# 19307           10 1984-09-21  Double Jeopardy!
# 19312           10 1984-09-21  Double Jeopardy!
# 19299           10 1984-09-21         Jeopardy!
# 19274           10 1984-09-21         Jeopardy!
# 19275           10 1984-09-21         Jeopardy!
# 19281           10 1984-09-21         Jeopardy!
# 19282           10 1984-09-21         Jeopardy!
# 19283           10 1984-09-21         Jeopardy!
# 19284           10 1984-09-21         Jeopardy!
# 19276           10 1984-09-21         Jeopardy!
# 19287           10 1984-09-21         Jeopardy!
# 19296           10 1984-09-21         Jeopardy!
# 19295           10 1984-09-21         Jeopardy!
# 19294           10 1984-09-21         Jeopardy!
# 19298           10 1984-09-21         Jeopardy!
# 19292           10 1984-09-21         Jeopardy!
# 19291           10 1984-09-21         Jeopardy!
# 19290           10 1984-09-21         Jeopardy!
# 19289           10 1984-09-21         Jeopardy!
# 19288           10 1984-09-21         Jeopardy!
# 19293           10 1984-09-21         Jeopardy!
# 19297           10 1984-09-21         Jeopardy!
# 19304           10 1984-09-21  Double Jeopardy!
# 19277           10 1984-09-21         Jeopardy!
# 19300           10 1984-09-21         Jeopardy!
# 19278           10 1984-09-21         Jeopardy!
# 19279           10 1984-09-21         Jeopardy!
# ...            ...        ...               ...
# 1972          6294 2012-01-19  Double Jeopardy!
# 1942          6294 2012-01-19         Jeopardy!
# 1920          6294 2012-01-19         Jeopardy!
# 1931          6294 2012-01-19         Jeopardy!
# 1923          6294 2012-01-19         Jeopardy!
# 1933          6294 2012-01-19         Jeopardy!
# 1924          6294 2012-01-19         Jeopardy!
# 1973          6294 2012-01-19  Double Jeopardy!
# 1926          6294 2012-01-19         Jeopardy!
# 1929          6294 2012-01-19         Jeopardy!
# 1930          6294 2012-01-19         Jeopardy!
# 1927          6294 2012-01-19         Jeopardy!
# 1928          6294 2012-01-19         Jeopardy!
# 1955          6294 2012-01-19  Double Jeopardy!
# 1943          6294 2012-01-19         Jeopardy!
# 1925          6294 2012-01-19         Jeopardy!
# 1964          6294 2012-01-19  Double Jeopardy!
# 1965          6294 2012-01-19  Double Jeopardy!
# 1966          6294 2012-01-19  Double Jeopardy!
# 1967          6294 2012-01-19  Double Jeopardy!
# 1968          6294 2012-01-19  Double Jeopardy!
# 1969          6294 2012-01-19  Double Jeopardy!
# 1970          6294 2012-01-19  Double Jeopardy!
# 1915          6294 2012-01-19         Jeopardy!
# 1921          6294 2012-01-19         Jeopardy!
# 1916          6294 2012-01-19         Jeopardy!
# 1917          6294 2012-01-19         Jeopardy!
# 1945          6294 2012-01-19  Double Jeopardy!
# 1961          6294 2012-01-19  Double Jeopardy!
# 1922          6294 2012-01-19         Jeopardy!
#
#                               Category   Value  \
# 19325                  U.S. PRESIDENTS    None
# 19305                         HOMONYMS    $200
# 19306                        TV TRIVIA    $200
# 19307                             1789    $400
# 19312                    TOURIST TRAPS    $600
# 19299                       "B" MOVIES    $500
# 19274                        GEOGRAPHY    $100
# 19275                      DOUBLE TALK    $100
# 19281                      DOUBLE TALK    $200
# 19282            "JACKS" OF ALL TRADES    $200
# 19283                            SHIPS    $200
# 19284                       "B" MOVIES    $200
# 19276            "JACKS" OF ALL TRADES    $100
# 19287            "JACKS" OF ALL TRADES    $300
# 19296                      DOUBLE TALK    $500
# 19295                        GEOGRAPHY    $500
# 19294                       "B" MOVIES    $400
# 19298                            SHIPS    $500
# 19292            "JACKS" OF ALL TRADES    $400
# 19291                      DOUBLE TALK    $400
# 19290                        GEOGRAPHY    $400
# 19289                       "B" MOVIES    $300
# 19288                            SHIPS    $300
# 19293                            SHIPS    $400
# 19297            "JACKS" OF ALL TRADES    $500
# 19304                       LITERATURE    $200
# 19277                            SHIPS    $100
# 19300                           SPORTS    $500
# 19278                       "B" MOVIES    $100
# 19279                           SPORTS    $100
# ...                                ...     ...
# 1972           ACTING PRESIDENTS ON TV   $2000
# 1942                            INLETS   $1000
# 1920                           FOREIGN    $200
# 1931          THE EVOLUTION OF "M"USIC    $600
# 1923                    NURSERY RHYMES    $400
# 1933   A SHAKESPEARE PLAY, FOR OPENERS    $800
# 1924                            INLETS    $400
# 1973                               4 N   $2000
# 1926                           FOREIGN    $400
# 1929                    NURSERY RHYMES    $600
# 1930                            INLETS  $1,000
# 1927   A SHAKESPEARE PLAY, FOR OPENERS    $600
# 1928                   THAT'S BUSINESS    $600
# 1955                               4 N    $800
# 1943          THE EVOLUTION OF "M"USIC   $1000
# 1925          THE EVOLUTION OF "M"USIC    $400
# 1964           WEAPONS OF WORLD WAR II   $1600
# 1965                 THE LIVING PLANET   $1600
# 1966           ACTING PRESIDENTS ON TV   $1600
# 1967                               4 N   $1600
# 1968                  AMERICAN HISTORY   $2000
# 1969                 WHAT'S YOUR BEEF?   $2000
# 1970           WEAPONS OF WORLD WAR II   $2000
# 1915   A SHAKESPEARE PLAY, FOR OPENERS    $200
# 1921   A SHAKESPEARE PLAY, FOR OPENERS    $400
# 1916                   THAT'S BUSINESS    $200
# 1917                    NURSERY RHYMES    $200
# 1945                  AMERICAN HISTORY    $400
# 1961                               4 N  $2,400
# 1922                   THAT'S BUSINESS    $400
#
#                                                 Question  \
# 19325  Adventurous 26th president, he was 1st to ride...
# 19305                 Hindu hierarchy or a play's actors
# 19306  Last season, this series mourned the loss of S...
# 19307       Why April 28th was a bad day for Capt. Bligh
# 19312  Since '27, stars have made good impressions at...
# 19299  Sensitive Mart Crowley treatment of gays march...
# 19274                                   Formerly Formosa
# 19275  Not a Hawaiian cow, but a dress worn by Hawaii...
# 19281          Affirmative reply to an admiral's command
# 19282  Between him & his wife, they licked the platte...
# 19283  Merchant ship that made the trip in 1620 from ...
# 19284  Burt Lancaster film in which his only friends ...
# 19276           He celebrated his 39th birthday 41 times
# 19287  He didn't find gold in the Klondike, so he wro...
# 19296  British rockers whose name came from villain i...
# 19295  About 1/3 of Africa's Pygmy population lives i...
# 19294  This title describes Carroll Baker's thumb-suc...
# 19298  At some 500' long & with 9 masts, the "Cheng H...
# 19292              His nickname was the "Manassa Mauler"
# 19291         Washington's panda with pregnancy problems
# 19290  First colony since 1776 to break from Britain ...
# 19289  Poignant movie in which Peter Sellers turned o...
# 19288  He entertained world leaders on his yacht "Chr...
# 19293                 Royal neighbor of the Spruce Goose
# 19297  2nd generation pop singer, he's sung on every ...
# 19304  Depending on the book, he could be a "Jones", ...
# 19277  "Unsinkable" for most of its maiden voyage in ...
# 19300  Boxer whose life was portrayed in "Somebody Up...
# 19278  In '61 movie, Audrey Hepburn's alternative to ...
# 19279             What Gary Player plays professionailly
# ...                                                  ...
# 1972                      Mary McDonnell as Laura Roslin
# 1942   North Carolina's Albemarle Sound is no deeper ...
# 1920      In Portuguese, domingo is this day of the week
# 1931   This singer of "Jack & Diane" had to fight to ...
# 1923   "I had a little hobby-horse and it was dapple ...
# 1933   Completes the opening sentence "Now is the win...
# 1924   Big ships must pass through Admiralty Inlet to...
# 1973   Inopportune or untimely, like the title "woman...
# 1926   In French, l'oiseau is this; it sports les plumes
# 1929   In a counting nursery rhyme, they were "a-cour...
# 1930   Faxa Bay in the North Atlantic is between this...
# 1927   The chorus of "Romeo & Juliet" tells us it's i...
# 1928   An Italian clothier is known as the United Col...
# 1955   "U" know it means not deliberate; I'm sorry, t...
# 1943   In the 2000s "Makes Me Wonder" got this group ...
# 1925   1974's "Mandy" was his first Top 40 hit--& it ...
# 1964   It was the alphanumeric designation of the U.S...
# 1965   (<a href="http://www.j-archive.com/media/2012-...
# 1966        On Fox, Patricia Wettig as Caroline Reynolds
# 1967   Adjective preceding the railroad completed in ...
# 1968   In 1917 the U.S. purchased the islands of St. ...
# 1969   To make this dish, beef is topped with pate de...
# 1970   "Hefty" nickname of the second & last atomic b...
# 1915   This play opens on the battlements of the cast...
# 1921   "Othello" opens with Roderigo addressing this ...
# 1916   He started a book business from his home in 18...
# 1917   Peter, Peter was an eater of this; he kept his...
# 1945   In December 1974 this former New York governor...
# 1961   It's the church festival on March 25 commemora...
# 1922   In 1997 Tyco International moved to this U.K. ...
#
#                                     Answer  \
# 19325                   Theodore Roosevelt
# 19305                       a caste (cast)
# 19306                    Hill Street Blues
# 19307  the day of the mutiny on the Bounty
# 19312               Mann's Chinese Theatre
# 19299                 The Boys in the Band
# 19274                               Taiwan
# 19275                             a muumuu
# 19281                              aye-aye
# 19282                          Jack Spratt
# 19283                        the Mayflower
# 19284              The Birdman of Alcatraz
# 19276                           Jack Benny
# 19287                          Jack London
# 19296                          Duran Duran
# 19295                                Zaire
# 19294                            Baby Doll
# 19298                               a junk
# 19292                         Jack Dempsey
# 19291                            Ling-Ling
# 19290                             Rhodesia
# 19289                          Being There
# 19288                  (Aristotle) Onassis
# 19293                       the Queen Mary
# 19297                           Jack Jones
# 19304                                  Tom
# 19277                          the Titanic
# 19300                       Rocky Graziano
# 19278               Breakfast at Tiffany's
# 19279                                 golf
# ...                                    ...
# 1972                  Battlestar Galactica
# 1942                       the Outer Banks
# 1920                                Sunday
# 1931                       John Mellencamp
# 1923                                   hay
# 1933                                  York
# 1924                           Puget Sound
# 1973                          inconvenient
# 1926                                a bird
# 1929                                 maids
# 1930                               Iceland
# 1927                                Verona
# 1928                              Benetton
# 1955                         unintentional
# 1943                              Maroon 5
# 1925                         Barry Manilow
# 1964                                the M1
# 1965                             arthropod
# 1966                          Prison Break
# 1967                      transcontinental
# 1968                               Denmark
# 1969                       beef Wellington
# 1970                               Fat Man
# 1915                                Hamlet
# 1921                                  Iago
# 1916                   (Charles M.) Barnes
# 1917                               pumpkin
# 1945                           Rockefeller
# 1961                      the annunciation
# 1922                               Bermuda
#
#                                           clean_question  \
# 19325  adventurous 26th president he was 1st to ride ...
# 19305                  hindu hierarchy or a plays actors
# 19306  last season this series mourned the loss of sg...
# 19307        why april 28th was a bad day for capt bligh
# 19312  since 27 stars have made good impressions at t...
# 19299  sensitive mart crowley treatment of gays march...
# 19274                                   formerly formosa
# 19275  not a hawaiian cow but a dress worn by hawaiia...
# 19281           affirmative reply to an admirals command
# 19282  between him  his wife they licked the platter ...
# 19283  merchant ship that made the trip in 1620 from ...
# 19284  burt lancaster film in which his only friends ...
# 19276           he celebrated his 39th birthday 41 times
# 19287  he didnt find gold in the klondike so he wrote...
# 19296  british rockers whose name came from villain i...
# 19295  about 13 of africas pygmy population lives in ...
# 19294  this title describes carroll bakers thumbsucki...
# 19298  at some 500 long  with 9 masts the cheng ho wa...
# 19292                his nickname was the manassa mauler
# 19291          washingtons panda with pregnancy problems
# 19290  first colony since 1776 to break from britain ...
# 19289  poignant movie in which peter sellers turned o...
# 19288  he entertained world leaders on his yacht chri...
# 19293                 royal neighbor of the spruce goose
# 19297  2nd generation pop singer hes sung on every lo...
# 19304  depending on the book he could be a jones a sa...
# 19277   unsinkable for most of its maiden voyage in 1912
# 19300  boxer whose life was portrayed in somebody up ...
# 19278  in 61 movie audrey hepburns alternative to bru...
# 19279             what gary player plays professionailly
# ...                                                  ...
# 1972                      mary mcdonnell as laura roslin
# 1942   north carolinas albemarle sound is no deeper t...
# 1920       in portuguese domingo is this day of the week
# 1931   this singer of jack  diane had to fight to rec...
# 1923   i had a little hobbyhorse and it was dapple gr...
# 1933   completes the opening sentence now is the wint...
# 1924   big ships must pass through admiralty inlet to...
# 1973   inopportune or untimely like the title woman i...
# 1926      in french loiseau is this it sports les plumes
# 1929   in a counting nursery rhyme they were acourtin...
# 1930   faxa bay in the north atlantic is between this...
# 1927   the chorus of romeo  juliet tells us its in th...
# 1928   an italian clothier is known as the united col...
# 1955   u know it means not deliberate im sorry that s...
# 1943   in the 2000s makes me wonder got this group no...
# 1925   1974s mandy was his first top 40 hit it reache...
# 1964   it was the alphanumeric designation of the us ...
# 1965   a href=httpwwwjarchivecommedia20120119dj27jpg ...
# 1966         on fox patricia wettig as caroline reynolds
# 1967   adjective preceding the railroad completed in ...
# 1968   in 1917 the us purchased the islands of st cro...
# 1969   to make this dish beef is topped with pate de ...
# 1970   hefty nickname of the second  last atomic bomb...
# 1915   this play opens on the battlements of the cast...
# 1921   othello opens with roderigo addressing this vi...
# 1916   he started a book business from his home in 18...
# 1917   peter peter was an eater of this he kept his w...
# 1945   in december 1974 this former new york governor...
# 1961   its the church festival on march 25 commemorat...
# 1922   in 1997 tyco international moved to this uk te...
#
#                               clean_answer  clean_value  answer_in_question  \
# 19325                   theodore roosevelt            0            0.000000
# 19305                         a caste cast          200            0.333333
# 19306                    hill street blues          200            0.000000
# 19307  the day of the mutiny on the bounty          400            0.142857
# 19312                manns chinese theatre          600            0.000000
# 19299                 the boys in the band          500            0.000000
# 19274                               taiwan          100            0.000000
# 19275                             a muumuu          100            0.500000
# 19281                               ayeaye          200            0.000000
# 19282                          jack spratt          200            0.000000
# 19283                        the mayflower          200            0.000000
# 19284              the birdman of alcatraz          200            0.000000
# 19276                           jack benny          100            0.000000
# 19287                          jack london          300            0.000000
# 19296                          duran duran          500            0.000000
# 19295                                zaire          500            0.000000
# 19294                            baby doll          400            0.000000
# 19298                               a junk          500            0.000000
# 19292                         jack dempsey          400            0.000000
# 19291                             lingling          400            0.000000
# 19290                             rhodesia          400            0.000000
# 19289                          being there          300            0.000000
# 19288                    aristotle onassis          300            0.000000
# 19293                       the queen mary          400            0.000000
# 19297                           jack jones          500            0.000000
# 19304                                  tom          200            0.000000
# 19277                          the titanic          100            0.000000
# 19300                       rocky graziano          500            0.000000
# 19278                breakfast at tiffanys          100            0.000000
# 19279                                 golf          100            0.000000
# ...                                    ...          ...                 ...
# 1972                  battlestar galactica         2000            0.000000
# 1942                       the outer banks         1000            0.000000
# 1920                                sunday          200            0.000000
# 1931                       john mellencamp          600            0.000000
# 1923                                   hay          400            0.000000
# 1933                                  york          800            0.000000
# 1924                           puget sound          400            0.500000
# 1973                          inconvenient         2000            0.000000
# 1926                                a bird          400            0.000000
# 1929                                 maids          600            0.000000
# 1930                               iceland         1000            0.000000
# 1927                                verona          600            0.000000
# 1928                              benetton          600            0.000000
# 1955                         unintentional          800            0.000000
# 1943                              maroon 5         1000            0.000000
# 1925                         barry manilow          400            0.000000
# 1964                                the m1         1600            0.000000
# 1965                             arthropod         1600            0.000000
# 1966                          prison break         1600            0.000000
# 1967                      transcontinental         1600            0.000000
# 1968                               denmark         2000            0.000000
# 1969                       beef wellington         2000            0.500000
# 1970                               fat man         2000            0.000000
# 1915                                hamlet          200            0.000000
# 1921                                  iago          400            0.000000
# 1916                      charles m barnes          200            0.000000
# 1917                               pumpkin          200            0.000000
# 1945                           rockefeller          400            0.000000
# 1961                      the annunciation         2400            0.000000
# 1922                               bermuda          400            0.000000
#
#        question_overlap
# 19325          0.000000
# 19305          0.000000
# 19306          0.000000
# 19307          0.000000
# 19312          0.000000
# 19299          0.000000
# 19274          0.000000
# 19275          0.090909
# 19281          0.000000
# 19282          0.000000
# 19283          0.000000
# 19284          0.000000
# 19276          0.000000
# 19287          0.000000
# 19296          0.000000
# 19295          0.000000
# 19294          0.000000
# 19298          0.000000
# 19292          0.000000
# 19291          0.000000
# 19290          0.000000
# 19289          0.000000
# 19288          0.000000
# 19293          0.000000
# 19297          0.000000
# 19304          0.000000
# 19277          0.000000
# 19300          0.000000
# 19278          0.000000
# 19279          0.000000
# ...                 ...
# 1972           0.000000
# 1942           0.157895
# 1920           0.222222
# 1931           0.000000
# 1923           0.000000
# 1933           0.222222
# 1924           0.200000
# 1973           0.083333
# 1926           0.000000
# 1929           0.250000
# 1930           0.307692
# 1927           0.000000
# 1928           0.090909
# 1955           0.125000
# 1943           0.100000
# 1925           0.090909
# 1964           0.181818
# 1965           0.090909
# 1966           0.428571
# 1967           0.571429
# 1968           0.200000
# 1969           0.095238
# 1970           0.083333
# 1915           0.062500
# 1921           0.125000
# 1916           0.190476
# 1917           0.000000
# 1945           0.214286
# 1961           0.250000
# 1922           0.266667
#
# [19999 rows x 12 columns]

# %%
question_overlap = []
terms_used = set()

jeopardy = jeopardy.sort_values("Air Date")

for i, row in jeopardy.iterrows():
        split_question = row["clean_question"].split(" ")
        split_question = [q for q in split_question if len(q) > 5]
        match_count = 0
        for word in split_question:
            if word in terms_used:
                match_count += 1
        for word in split_question:
            terms_used.add(word)
        if len(split_question) > 0:
            match_count /= len(split_question)
        question_overlap.append(match_count)
jeopardy["question_overlap"] = question_overlap

jeopardy["question_overlap"].mean()
# Out:
# 0.6871708558735073

# %% [markdown]
# So on average, up to 68% of questions are "recycled" and are repeats of older questions

# %% [markdown]
# ## Studying High Value Questions

# %% [markdown]
# Let's say we only want to study questions that pertain to high value questions instead of low value questions. This will help you earn more money when you're on Jeopardy.
#
# We can actually figure out which terms correspond to high-value questions using a chi-squared test. We'll first need to narrow down the questions into two categories:
#
# - Low value -- Any row where Value is less than 800.
# - High value -- Any row where Value is greater than 800.
#
# We'll then be able to loop through each of the terms from the last calculation, terms_used, and:
#
# - Find the number of low value questions the word occurs in.
# - Find the number of high value questions the word occurs in.
# - Find the percentage of questions the word occurs in.
# - Based on the percentage of questions the word occurs in, find expected counts.
# - Compute the chi squared value based on the expected counts and the observed counts for high and low value questions.
#
# We can then find the words with the biggest differences in usage between high and low value questions, by selecting the words with the highest associated chi-squared values. Doing this for all of the words would take a very long time, so we'll just do it for a small sample now.

# %%
def sorter(row):
    if row['clean_value'] > 800:
        value = 1
    else:
        value = 0
    return value

jeopardy['high_value'] = jeopardy.apply(sorter, axis=1)

# %%
jeopardy
# Out:
#        Show Number   Air Date             Round  \
# 19325           10 1984-09-21   Final Jeopardy!
# 19278           10 1984-09-21         Jeopardy!
# 19279           10 1984-09-21         Jeopardy!
# 19280           10 1984-09-21         Jeopardy!
# 19286           10 1984-09-21         Jeopardy!
# 19285           10 1984-09-21         Jeopardy!
# 19324           10 1984-09-21  Double Jeopardy!
# 19301           10 1984-09-21  Double Jeopardy!
# 19308           10 1984-09-21  Double Jeopardy!
# 19309           10 1984-09-21  Double Jeopardy!
# 19310           10 1984-09-21  Double Jeopardy!
# 19311           10 1984-09-21  Double Jeopardy!
# 19302           10 1984-09-21  Double Jeopardy!
# 19313           10 1984-09-21  Double Jeopardy!
# 19314           10 1984-09-21  Double Jeopardy!
# 19315           10 1984-09-21  Double Jeopardy!
# 19316           10 1984-09-21  Double Jeopardy!
# 19317           10 1984-09-21  Double Jeopardy!
# 19318           10 1984-09-21  Double Jeopardy!
# 19319           10 1984-09-21  Double Jeopardy!
# 19320           10 1984-09-21  Double Jeopardy!
# 19321           10 1984-09-21  Double Jeopardy!
# 19322           10 1984-09-21  Double Jeopardy!
# 19323           10 1984-09-21  Double Jeopardy!
# 19300           10 1984-09-21         Jeopardy!
# 19277           10 1984-09-21         Jeopardy!
# 19303           10 1984-09-21  Double Jeopardy!
# 19297           10 1984-09-21         Jeopardy!
# 19304           10 1984-09-21  Double Jeopardy!
# 19305           10 1984-09-21  Double Jeopardy!
# ...            ...        ...               ...
# 1963          6294 2012-01-19  Double Jeopardy!
# 1961          6294 2012-01-19  Double Jeopardy!
# 1958          6294 2012-01-19  Double Jeopardy!
# 1957          6294 2012-01-19  Double Jeopardy!
# 1956          6294 2012-01-19  Double Jeopardy!
# 1959          6294 2012-01-19  Double Jeopardy!
# 1934          6294 2012-01-19         Jeopardy!
# 1919          6294 2012-01-19         Jeopardy!
# 1936          6294 2012-01-19         Jeopardy!
# 1940          6294 2012-01-19         Jeopardy!
# 1937          6294 2012-01-19         Jeopardy!
# 1938          6294 2012-01-19         Jeopardy!
# 1939          6294 2012-01-19         Jeopardy!
# 1918          6294 2012-01-19         Jeopardy!
# 1962          6294 2012-01-19  Double Jeopardy!
# 1974          6294 2012-01-19   Final Jeopardy!
# 1932          6294 2012-01-19         Jeopardy!
# 1944          6294 2012-01-19         Jeopardy!
# 1946          6294 2012-01-19  Double Jeopardy!
# 1947          6294 2012-01-19  Double Jeopardy!
# 1948          6294 2012-01-19  Double Jeopardy!
# 1949          6294 2012-01-19  Double Jeopardy!
# 1950          6294 2012-01-19  Double Jeopardy!
# 1951          6294 2012-01-19  Double Jeopardy!
# 1952          6294 2012-01-19  Double Jeopardy!
# 1953          6294 2012-01-19  Double Jeopardy!
# 1954          6294 2012-01-19  Double Jeopardy!
# 1971          6294 2012-01-19  Double Jeopardy!
# 1941          6294 2012-01-19         Jeopardy!
# 1922          6294 2012-01-19         Jeopardy!
#
#                               Category   Value  \
# 19325                  U.S. PRESIDENTS    None
# 19278                       "B" MOVIES    $100
# 19279                           SPORTS    $100
# 19280                        GEOGRAPHY    $200
# 19286                      DOUBLE TALK    $300
# 19285                        GEOGRAPHY    $300
# 19324                        TV TRIVIA   $1000
# 19301                     LABOR UNIONS    $200
# 19308                    TOURIST TRAPS    $400
# 19309                       LITERATURE    $400
# 19310                         HOMONYMS    $400
# 19311                        TV TRIVIA    $400
# 19302                             1789    $200
# 19313                       LITERATURE    $600
# 19314                         HOMONYMS    $600
# 19315                        TV TRIVIA    $600
# 19316                    TOURIST TRAPS    $800
# 19317                       LITERATURE    $800
# 19318                         HOMONYMS  $1,000
# 19319                        TV TRIVIA    $800
# 19320                             1789   $1000
# 19321                    TOURIST TRAPS   $1000
# 19322                       LITERATURE   $1000
# 19323                         HOMONYMS   $1000
# 19300                           SPORTS    $500
# 19277                            SHIPS    $100
# 19303                    TOURIST TRAPS    $200
# 19297            "JACKS" OF ALL TRADES    $500
# 19304                       LITERATURE    $200
# 19305                         HOMONYMS    $200
# ...                                ...     ...
# 1963                 WHAT'S YOUR BEEF?   $1600
# 1961                               4 N  $2,400
# 1958           WEAPONS OF WORLD WAR II   $1200
# 1957                 WHAT'S YOUR BEEF?   $1200
# 1956                  AMERICAN HISTORY  $1,800
# 1959                 THE LIVING PLANET   $1200
# 1934                   THAT'S BUSINESS    $800
# 1919          THE EVOLUTION OF "M"USIC    $200
# 1936                            INLETS    $800
# 1940                   THAT'S BUSINESS   $1000
# 1937          THE EVOLUTION OF "M"USIC    $800
# 1938                           FOREIGN    $800
# 1939   A SHAKESPEARE PLAY, FOR OPENERS   $1000
# 1918                            INLETS    $200
# 1962                  AMERICAN HISTORY   $1600
# 1974               SPORTS & THE MOVIES    None
# 1932                           FOREIGN    $600
# 1944                           FOREIGN   $1000
# 1946                 WHAT'S YOUR BEEF?    $400
# 1947           WEAPONS OF WORLD WAR II    $400
# 1948                 THE LIVING PLANET    $400
# 1949           ACTING PRESIDENTS ON TV    $400
# 1950                               4 N    $400
# 1951                  AMERICAN HISTORY    $800
# 1952                 WHAT'S YOUR BEEF?    $800
# 1953           WEAPONS OF WORLD WAR II    $800
# 1954           ACTING PRESIDENTS ON TV    $800
# 1971                 THE LIVING PLANET   $2000
# 1941                    NURSERY RHYMES   $1000
# 1922                   THAT'S BUSINESS    $400
#
#                                                 Question  \
# 19325  Adventurous 26th president, he was 1st to ride...
# 19278  In '61 movie, Audrey Hepburn's alternative to ...
# 19279             What Gary Player plays professionailly
# 19280  Dutch is still an official language in what is...
# 19286              Adopted baby of Barney & Betty Rubble
# 19285  8th most populous country in the world, this "...
# 19324  In court, he'd always make mincemeat of Hamilt...
# 19301           Notorious labor leader missing since '75
# 19308  Seaside resort that has a monopoly on East Coa...
# 19309  He wrote "The 3 Musketeers"; his son wrote "Ca...
# 19310                                 Near or a purchase
# 19311          He went from the Ponderosa to the prairie
# 19302  Washington proclaimed Nov. 26, 1789 this first...
# 19313     Where you can't go again in Thomas Wolfe title
# 19314            A fixed look, or Ginger Rogers' partner
# 19315                   In 1970 he had a "Goodtime Hour"
# 19316  A thrilling destination for tight-rope walkers...
# 19317  Irving's bird-like hero chased by the Headless...
# 19318                                 Didn't see the fog
# 19319  Jackie Gleason show that rejected titles "The ...
# 19320  Now totaling over $1 trillion, it began 11 day...
# 19321  Tourists know this Catholic mission as Davy Cr...
# 19322                              Shaw's scorched saint
# 19323        Where ships dock or what a jury consists of
# 19300  Boxer whose life was portrayed in "Somebody Up...
# 19277  "Unsinkable" for most of its maiden voyage in ...
# 19303  Both Ferde Grofe' & the Colorado River dug thi...
# 19297  2nd generation pop singer, he's sung on every ...
# 19304  Depending on the book, he could be a "Jones", ...
# 19305                 Hindu hierarchy or a play's actors
# ...                                                  ...
# 1963   The second word in the French name of this bon...
# 1961   It's the church festival on March 25 commemora...
# 1958   Today, this Japanese car company makes the gal...
# 1957   A New York steak is also known as this alliter...
# 1956   This political party founded around 1789 stood...
# 1959   Relative to the size of the bird, this flightl...
# 1934   In 1851 this company started using a logo with...
# 1919   This '60s "Nights in White Satin" band has ano...
# 1936   This Chilean city whose name means "valley of ...
# 1940   In 1927 this brand name first appeared on a Se...
# 1937   In the '90s it was "Enter Sandman" with this g...
# 1938      Tredici is Italian for this symbol of bad luck
# 1939   This play opens most dramatically with thunder...
# 1918   This largest Alaskan city lies at the head of ...
# 1962   His foes said that in 1877 he agreed to withdr...
# 1974   When asked for a home address in "The Blues Br...
# 1932     If Popeye spoke Hebrew he'd ask for tered, this
# 1944   In German, berg is this topographical feature ...
# 1946   If you can't stand the heat, there's always th...
# 1947   The British A22 Mark IV tank carried a 75-mill...
# 1948   Able to lift 850 times its own weight, the str...
# 1949         Blair Underwood as President Elias Martinez
# 1950   Number of "beers on the wall" at the beginning...
# 1951   In 1951 he told a joint session of congress th...
# 1952   A New England boiled dinner is traditionally m...
# 1953   Ships in the U.S. Navy's Casablanca class of "...
# 1954   Dennis Haysbert & D.B. Woodside as David & Way...
# 1971   The April 2009 issue of Science magazine repor...
# 1941   "Here we go round" this bush "on a cold and fr...
# 1922   In 1997 Tyco International moved to this U.K. ...
#
#                           Answer  \
# 19325         Theodore Roosevelt
# 19278     Breakfast at Tiffany's
# 19279                       golf
# 19280               Dutch Guiana
# 19286                  Bamm-Bamm
# 19285                 Bangladesh
# 19324                Perry Mason
# 19301                Jimmy Hoffa
# 19308  Atlantic City, New Jersey
# 19309          (Alexandre) Dumas
# 19310                   by (buy)
# 19311             Michael Landon
# 19302               Thanksgiving
# 19313                       home
# 19314          a stare (Astaire)
# 19315              Glen Campbell
# 19316              Niagara Falls
# 19317              Ichabod Crane
# 19318              missed (mist)
# 19319           The Honeymooners
# 19320          the national debt
# 19321                  the Alamo
# 19322            St. Joan of Arc
# 19323              piers (peers)
# 19300             Rocky Graziano
# 19277                the Titanic
# 19303           the Grand Canyon
# 19297                 Jack Jones
# 19304                        Tom
# 19305             a caste (cast)
# ...                          ...
# 1963                filet mignon
# 1961            the annunciation
# 1958                  Mitsubishi
# 1957                 strip steak
# 1956             the Federalists
# 1959                    the kiwi
# 1934            Proctor & Gamble
# 1919                 Moody Blues
# 1936                  Valparaiso
# 1940                     Kenmore
# 1937                   Metallica
# 1938                    thirteen
# 1939                 The Tempest
# 1918                   Anchorage
# 1962       (Rutherford B.) Hayes
# 1974               Wrigley Field
# 1932                     spinach
# 1944                  a mountain
# 1946               steak tartare
# 1947                   Churchill
# 1948                      beetle
# 1949                   The Event
# 1950                 ninety-nine
# 1951          (Douglas) McArthur
# 1952                 corned beef
# 1953           aircraft carriers
# 1954                          24
# 1971                their genome
# 1941           the mulberry bush
# 1922                     Bermuda
#
#                                           clean_question  \
# 19325  adventurous 26th president he was 1st to ride ...
# 19278  in 61 movie audrey hepburns alternative to bru...
# 19279             what gary player plays professionailly
# 19280  dutch is still an official language in what is...
# 19286               adopted baby of barney  betty rubble
# 19285  8th most populous country in the world this be...
# 19324  in court hed always make mincemeat of hamilton...
# 19301            notorious labor leader missing since 75
# 19308  seaside resort that has a monopoly on east coa...
# 19309    he wrote the 3 musketeers his son wrote camille
# 19310                                 near or a purchase
# 19311          he went from the ponderosa to the prairie
# 19302  washington proclaimed nov 26 1789 this first n...
# 19313      where you cant go again in thomas wolfe title
# 19314              a fixed look or ginger rogers partner
# 19315                     in 1970 he had a goodtime hour
# 19316  a thrilling destination for tightrope walkers ...
# 19317  irvings birdlike hero chased by the headless h...
# 19318                                  didnt see the fog
# 19319  jackie gleason show that rejected titles the l...
# 19320  now totaling over 1 trillion it began 11 days ...
# 19321  tourists know this catholic mission as davy cr...
# 19322                               shaws scorched saint
# 19323        where ships dock or what a jury consists of
# 19300  boxer whose life was portrayed in somebody up ...
# 19277   unsinkable for most of its maiden voyage in 1912
# 19303  both ferde grofe  the colorado river dug this ...
# 19297  2nd generation pop singer hes sung on every lo...
# 19304  depending on the book he could be a jones a sa...
# 19305                  hindu hierarchy or a plays actors
# ...                                                  ...
# 1963   the second word in the french name of this bon...
# 1961   its the church festival on march 25 commemorat...
# 1958   today this japanese car company makes the gala...
# 1957   a new york steak is also known as this alliter...
# 1956   this political party founded around 1789 stood...
# 1959   relative to the size of the bird this flightle...
# 1934   in 1851 this company started using a logo with...
# 1919   this 60s nights in white satin band has anothe...
# 1936   this chilean city whose name means valley of p...
# 1940   in 1927 this brand name first appeared on a se...
# 1937     in the 90s it was enter sandman with this group
# 1938      tredici is italian for this symbol of bad luck
# 1939   this play opens most dramatically with thunder...
# 1918   this largest alaskan city lies at the head of ...
# 1962   his foes said that in 1877 he agreed to withdr...
# 1974   when asked for a home address in the blues bro...
# 1932       if popeye spoke hebrew hed ask for tered this
# 1944   in german berg is this topographical feature o...
# 1946   if you cant stand the heat theres always this ...
# 1947   the british a22 mark iv tank carried a 75milli...
# 1948   able to lift 850 times its own weight the stro...
# 1949         blair underwood as president elias martinez
# 1950   number of beers on the wall at the beginning o...
# 1951   in 1951 he told a joint session of congress th...
# 1952   a new england boiled dinner is traditionally m...
# 1953   ships in the us navys casablanca class of esco...
# 1954   dennis haysbert  db woodside as david  wayne p...
# 1971   the april 2009 issue of science magazine repor...
# 1941   here we go round this bush on a cold and frost...
# 1922   in 1997 tyco international moved to this uk te...
#
#                    clean_answer  clean_value  answer_in_question  \
# 19325        theodore roosevelt            0            0.000000
# 19278     breakfast at tiffanys          100            0.000000
# 19279                      golf          100            0.000000
# 19280              dutch guiana          200            0.500000
# 19286                  bammbamm          300            0.000000
# 19285                bangladesh          300            0.000000
# 19324               perry mason         1000            0.000000
# 19301               jimmy hoffa          200            0.000000
# 19308  atlantic city new jersey          400            0.000000
# 19309           alexandre dumas          400            0.000000
# 19310                    by buy          400            0.000000
# 19311            michael landon          400            0.000000
# 19302              thanksgiving          200            0.000000
# 19313                      home          600            0.000000
# 19314           a stare astaire          600            0.333333
# 19315             glen campbell          600            0.000000
# 19316             niagara falls          800            0.000000
# 19317             ichabod crane          800            0.000000
# 19318               missed mist         1000            0.000000
# 19319          the honeymooners          800            0.000000
# 19320         the national debt         1000            0.000000
# 19321                 the alamo         1000            0.000000
# 19322            st joan of arc         1000            0.000000
# 19323               piers peers         1000            0.000000
# 19300            rocky graziano          500            0.000000
# 19277               the titanic          100            0.000000
# 19303          the grand canyon          200            0.000000
# 19297                jack jones          500            0.000000
# 19304                       tom          200            0.000000
# 19305              a caste cast          200            0.333333
# ...                         ...          ...                 ...
# 1963               filet mignon         1600            0.000000
# 1961           the annunciation         2400            0.000000
# 1958                 mitsubishi         1200            0.000000
# 1957                strip steak         1200            0.500000
# 1956            the federalists         1800            0.000000
# 1959                   the kiwi         1200            0.000000
# 1934            proctor  gamble          800            0.000000
# 1919                moody blues          200            0.000000
# 1936                 valparaiso          800            0.000000
# 1940                    kenmore         1000            0.000000
# 1937                  metallica          800            0.000000
# 1938                   thirteen          800            0.000000
# 1939                the tempest         1000            0.000000
# 1918                  anchorage          200            0.000000
# 1962         rutherford b hayes         1600            0.000000
# 1974              wrigley field            0            0.000000
# 1932                    spinach          600            0.000000
# 1944                 a mountain         1000            0.500000
# 1946              steak tartare          400            0.000000
# 1947                  churchill          400            0.000000
# 1948                     beetle          400            0.000000
# 1949                  the event          400            0.000000
# 1950                 ninetynine          400            0.000000
# 1951           douglas mcarthur          800            0.000000
# 1952                corned beef          800            0.000000
# 1953          aircraft carriers          800            0.000000
# 1954                         24          800            0.000000
# 1971               their genome         2000            0.000000
# 1941          the mulberry bush         1000            0.500000
# 1922                    bermuda          400            0.000000
#
#        question_overlap  high_value
# 19325          0.000000           0
# 19278          0.000000           0
# 19279          0.000000           0
# 19280          0.000000           0
# 19286          0.000000           0
# 19285          0.000000           0
# 19324          0.000000           1
# 19301          0.000000           0
# 19308          0.000000           0
# 19309          0.000000           0
# 19310          0.000000           0
# 19311          0.000000           0
# 19302          0.000000           0
# 19313          0.000000           0
# 19314          0.000000           0
# 19315          0.000000           0
# 19316          0.000000           0
# 19317          0.000000           0
# 19318          0.000000           1
# 19319          0.000000           0
# 19320          0.000000           1
# 19321          0.000000           1
# 19322          0.000000           1
# 19323          0.000000           1
# 19300          0.000000           0
# 19277          0.000000           0
# 19303          0.500000           0
# 19297          0.333333           0
# 19304          0.000000           0
# 19305          0.000000           0
# ...                 ...         ...
# 1963           1.000000           1
# 1961           1.000000           1
# 1958           0.800000           1
# 1957           1.000000           1
# 1956           1.000000           1
# 1959           1.000000           1
# 1934           1.000000           0
# 1919           1.000000           0
# 1936           1.000000           0
# 1940           1.000000           1
# 1937           1.000000           0
# 1938           0.666667           0
# 1939           0.666667           1
# 1918           1.000000           0
# 1962           1.000000           1
# 1974           1.000000           0
# 1932           1.000000           0
# 1944           0.666667           1
# 1946           0.833333           0
# 1947           0.750000           0
# 1948           0.800000           0
# 1949           1.000000           0
# 1950           1.000000           0
# 1951           1.000000           0
# 1952           1.000000           0
# 1953           1.000000           0
# 1954           0.600000           0
# 1971           1.000000           1
# 1941           0.500000           1
# 1922           1.000000           0
#
# [19999 rows x 13 columns]

# %%
#Function that narrows the word into high value and low value based on it's count in all of the rows
def word_value(word):
    low_count = 0
    high_count = 0
    for index, row in jeopardy.iterrows():
        if term in row["clean_question"].split(" "):
            if row["high_value"] == 1:
                high_count += 1
            else:
                low_count += 1
    return high_count, low_count

#Randomly pick ten elements of terms_used and append them to a list called comparison_terms.
comparison_terms = []
for i in range(10):
    comparison_terms.append(random.choice(list(terms_used)))
    
observed_expected = []
for term in comparison_terms:
    observed_expected.append(word_value(word))
    
observed_expected
# Out:
# [(1, 0),
#  (0, 1),
#  (1, 0),
#  (0, 2),
#  (2, 8),
#  (0, 1),
#  (0, 1),
#  (0, 1),
#  (1, 2),
#  (7, 9)]

# %% [markdown]
# Now that we've found the observed counts for a few terms, we can compute the expected counts and the chi-squared value.

# %%
high_value_count = len(jeopardy[jeopardy['high_value']==1]) #Find the number of rows in jeopardy where high_value is 1
low_value_count = len(jeopardy[jeopardy['high_value']==0]) #Find the number of rows in jeopardy where high_value is 0

# %%
chi_squared = []
for items in observed_expected: #Loop through each list in observed_expected
    total = items[0] + items[1] #Add up both items in the list (high and low counts) to get the total count
    total_prop = total/len(jeopardy) #Divide total by the number of rows in jeopardy to get the proportion across the dataset
    expected_high = total_prop*high_value_count
    expected_low = total_prop*low_value_count
    
    observed = np.array([items[0], items[1]])
    expected = np.array([expected_high, expected_low])
    chi_squared.append(chisquare(observed, expected))
    
chi_squared
# Out:
# [Power_divergenceResult(statistic=2.487792117195675, pvalue=0.11473257634454047),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=2.487792117195675, pvalue=0.11473257634454047),
#  Power_divergenceResult(statistic=0.803925692253768, pvalue=0.3699222378079571),
#  Power_divergenceResult(statistic=0.36767906209032747, pvalue=0.5442721040962595),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=0.03188116723440362, pvalue=0.8582887163235293),
#  Power_divergenceResult(statistic=1.7788002674291046, pvalue=0.18229671571722328)]

# %% [markdown]
# None of the terms had a significant difference in usage between high value and low value rows. Additionally, the frequencies were all lower than 5, so the chi-squared test isn't as valid. It would be better to run this test with only terms that have higher frequencies.

# %% [markdown]
# ## Next Steps

# %% [markdown]
# Here are some potential next steps:
#
# - Find a better way to eliminate non-informative words than just removing words that are less than 6 characters long. Some ideas:
#     - Manually create a list of words to remove, like the, than, etc.
#     - Find a list of stopwords to remove.
#     - Remove words that occur in more than a certain percentage (like 5%) of questions.
# - Perform the chi-squared test across more terms to see what terms have larger differences. This is hard to do currently because the code is slow, but here are some ideas:
#     - Use the apply method to make the code that calculates frequencies more efficient.
#     - Only select terms that have high frequencies across the dataset, and ignore the others.
# - Look more into the Category column and see if any interesting analysis can be done with it. Some ideas:
#     - See which categories appear the most often.
#     - Find the probability of each category appearing in each round.
# - Use the whole Jeopardy dataset instead of the subset we used in this project.
# - Use phrases instead of single words when seeing if there's overlap between questions. Single words don't capture the whole context of the question well.
